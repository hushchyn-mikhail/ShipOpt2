# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import GPy
import GPyOpt
import sys
from matplotlib.collections import EllipseCollection

# %matplotlib inline

# %%
observations = pd.read_csv('data/observations_500_ggpm.csv')

# %%
observations.tail(10)
# Out:
#      pitch  yoffset_layer  yoffset_plane  zshift_layer  zshift_plane  \
# 104    3.6       3.594696       4.494813      3.049733      5.044897
# 105    3.6       3.381300       3.201295      2.964961      4.964971
# 106    3.6       3.474086       2.312701      2.255825      4.259470
# 107    3.6       3.598140       0.924076      2.936921      5.004389
# 108    3.6       3.059157       3.450133      3.067241      5.034205
# 109    3.6       3.599984       4.499993      5.055909      7.055866
# 110    3.6       3.285834       3.903009      3.010154      5.010708
# 111    3.6       2.804555       3.331921      3.072888      4.970013
# 112    3.6       3.588030       3.512579      2.912248      5.156546
# 113    3.6       3.597515       4.497236      2.998454      4.977943
#
#      zshift_view      alpha  reconstructible  reco_passed_no_clones
# 104    10.097211  14.996806            207.0                  196.0
# 105    10.002917  10.834331            160.0                  153.0
# 106    10.015729  14.994279            188.0                  183.0
# 107    10.007410  11.394868            158.0                  148.0
# 108    10.064226   5.298193            146.0                  143.0
# 109    14.111810   5.000026            186.0                  178.0
# 110    10.000166  14.992646            174.0                  160.0
# 111    10.042298   5.200114            144.0                  138.0
# 112    10.054249   5.079693            164.0                  161.0
# 113    10.000000  14.992319            174.0                  160.0

# %%
design = observations.dropna()[observations.columns[:-2]].values
trials = observations.dropna()[['reconstructible']].values
y = observations.dropna()[['reco_passed_no_clones']].values

kernel = GPy.kern.RBF(input_dim=7)
ggpm = GPy.core.GP(design, y, kernel=kernel, 
                   Y_metadata={'trials': trials},
                   inference_method=GPy.inference.latent_function_inference.laplace.Laplace(),
                   likelihood=GPy.likelihoods.Binomial())

# %%
ggpm.optimize_restarts(messages=True)
# Out:
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s20  0002   3.057071e+02   6.775759e-11
# Runtime:     00s20
# Optimization status: Converged
#
# Optimization restart 1/10, f = 305.7070554913128
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s14  0001   4.904268e+02   6.915149e+03
#     01s21  0007   3.192353e+02   9.446043e-01
#     02s88  0039   3.057081e+02   1.406342e-06
# Runtime:     02s88
# Optimization status: Converged
#
# Optimization restart 2/10, f = 305.70814842393304
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     01s13  0014   3.125710e+02   1.952734e-01
#     03s20  0034   3.057174e+02   6.947932e-06
#     04s58  0047   3.057072e+02   7.538521e-11
# Runtime:     04s58
# Optimization status: Converged
#
# Optimization restart 3/10, f = 305.7071896383065
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     02s09  0012   3.150854e+02   1.573036e-01
#     06s67  0051   3.057071e+02   5.860971e-11
# Runtime:     06s67
# Optimization status: Converged
#
# Optimization restart 4/10, f = 305.70705122051777
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     02s02  0014   9.251352e+03   2.404132e+05
#     04s69  0054   3.057070e+02   5.187429e-11
# Runtime:     04s69
# Optimization status: Converged
#
# Optimization restart 5/10, f = 305.70704833659937
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s11  0001   5.247961e+02   3.921139e+03
#     03s29  0023   3.060029e+02   1.495573e-03
#     07s78  0054   3.057070e+02   1.146302e-11
# Runtime:     07s78
# Optimization status: Converged
#
# Optimization restart 6/10, f = 305.7069994934318
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s00  0000   6.229889e+02   1.146302e-11
#     02s18  0010   3.183691e+02   8.448180e-01
#     06s54  0037   3.057096e+02   1.413369e-07
#     07s26  0050   3.057070e+02   6.883686e-11
# Runtime:     07s26
# Optimization status: Converged
#
# Optimization restart 7/10, f = 305.7070221319106
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s13  0001   4.677648e+02   1.605153e+04
#     02s34  0018   3.074323e+02   5.211109e-04
#     05s97  0051   3.057070e+02   4.026885e-08
# Runtime:     05s97
# Optimization status: Converged
#
# Optimization restart 8/10, f = 305.70702028457515
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     02s07  0009   3.184856e+02   6.429434e-01
#     05s26  0032   3.057193e+02   8.701574e-06
#     07s02  0050   3.057071e+02   3.177380e-08
# Runtime:     07s02
# Optimization status: Converged
#
# Optimization restart 9/10, f = 305.70705683315657
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     01s32  0006   3.171207e+02   2.523867e-01
#     04s50  0027   3.057335e+02   8.688907e-05
#     06s30  0051   3.057070e+02   8.647940e-11
# Runtime:     06s30
# Optimization status: Converged
#
# Optimization restart 10/10, f = 305.707003538589
# [<paramz.optimization.optimization.opt_lbfgsb at 0x7f816c5aaba8>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f816c5a16a0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f816c5a17f0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f816c5aada0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f816c599208>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f816c5990b8>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f816c599278>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f816c599390>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f816c599240>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f816c5995c0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f816c5994e0>]

# %%
lik = GPy.likelihoods.Bernoulli()
values = lik.gp_link.transf(ggpm._raw_predict(design)[0])

# %%
arm = np.array(values).argmax()
arm
# Out:
# 97

# %%
values
# Out:
# array([[0.94704863],
#        [0.94704863],
#        [0.94704864],
#        [0.94704861],
#        [0.94704861],
#        [0.94704862],
#        [0.94704861],
#        [0.9470486 ],
#        [0.94704861],
#        [0.94704863],
#        [0.9470486 ],
#        [0.94704861],
#        [0.94704863],
#        [0.94704861],
#        [0.94704862],
#        [0.94704862],
#        [0.94704862],
#        [0.94704861],
#        [0.94704861],
#        [0.94704862],
#        [0.9470486 ],
#        [0.94704863],
#        [0.94704862],
#        [0.94704862],
#        [0.9470486 ],
#        [0.9470486 ],
#        [0.9470486 ],
#        [0.9470486 ],
#        [0.94704862],
#        [0.9470486 ],
#        [0.94704864],
#        [0.9470486 ],
#        [0.9470486 ],
#        [0.94704863],
#        [0.94704864],
#        [0.94704861],
#        [0.94704861],
#        [0.94704861],
#        [0.94704863],
#        [0.94704864],
#        [0.94704859],
#        [0.9470486 ],
#        [0.9470486 ],
#        [0.9470486 ],
#        [0.94704864],
#        [0.9470486 ],
#        [0.94704864],
#        [0.94704864],
#        [0.94704861],
#        [0.94704862],
#        [0.94704861],
#        [0.9470486 ],
#        [0.94704863],
#        [0.94704864],
#        [0.94704861],
#        [0.9470486 ],
#        [0.94704861],
#        [0.94704864],
#        [0.94704862],
#        [0.94704862],
#        [0.94704864],
#        [0.94704862],
#        [0.9470486 ],
#        [0.94704863],
#        [0.94704862],
#        [0.94704861],
#        [0.9470486 ],
#        [0.9470486 ],
#        [0.94704862],
#        [0.94704864],
#        [0.9470486 ],
#        [0.94704864],
#        [0.94704864],
#        [0.94704862],
#        [0.9470486 ],
#        [0.9470486 ],
#        [0.9470486 ],
#        [0.9470486 ],
#        [0.9470486 ],
#        [0.94704859],
#        [0.9470486 ],
#        [0.9470486 ],
#        [0.94704864],
#        [0.94704863],
#        [0.9470486 ],
#        [0.94704862],
#        [0.94704859],
#        [0.94704864],
#        [0.94704862],
#        [0.9470486 ],
#        [0.94704862],
#        [0.94704864],
#        [0.94704861],
#        [0.9470486 ],
#        [0.9470486 ],
#        [0.94704863],
#        [0.94704864],
#        [0.94704864],
#        [0.94704864],
#        [0.94704864],
#        [0.94704859],
#        [0.94704862],
#        [0.9470486 ],
#        [0.94704864],
#        [0.9470486 ],
#        [0.94704862],
#        [0.9470486 ],
#        [0.94704862],
#        [0.94704864],
#        [0.94704864],
#        [0.9470486 ],
#        [0.94704864],
#        [0.94704864],
#        [0.9470486 ]])
