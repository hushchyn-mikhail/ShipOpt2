# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import GPy
import GPyOpt
import sys
from matplotlib.collections import EllipseCollection

sys.path.append("../code")

from feasible_region import space, constraints

# %matplotlib inline

# %%
observations = pd.read_csv('../observations/observations.csv')

# %%
observations.tail(10)
# Out:
#       pitch  yoffset_layer  yoffset_plane  zshift_layer  zshift_plane  \
# 1507    3.6       1.800000       1.763174      2.115356      6.316354
# 1508    3.6       1.800000       3.163943      2.062593      5.871274
# 1509    3.6       1.800000       4.312412      1.743024      6.489525
# 1510    3.6       1.800000       1.633685      1.600000      5.744628
# 1511    3.6       1.800000       3.880907      2.150047      4.268312
# 1512    3.6       1.804027       2.793261      2.063883      5.255963
# 1513    3.6       1.800000       4.500000      2.103770      6.389612
# 1514    3.6       1.839467       1.235724      2.442135      5.972601
# 1515    3.6       1.808605       3.048815      2.085691      5.001062
# 1516    3.6       1.800000       4.329547      1.600000      5.548005
#
#       zshift_view  alpha  objective
# 1507         10.0    5.0   1.000000
# 1508         10.0    5.0   1.000000
# 1509         10.0    5.0   1.000000
# 1510         10.0    5.0   1.000000
# 1511         10.0    5.0   1.000000
# 1512         10.0    5.0   1.000000
# 1513         10.0    5.0   1.000000
# 1514         10.0    5.0   1.000000
# 1515         10.0    5.0   1.000000
# 1516         10.0    5.0   0.997253

# %%
plt.figure(figsize=(16, 9))
plt.subplot(2, 2, 1)
plt.title('Efficiency vs yoffset_layer')
plt.scatter(observations.yoffset_layer[:], observations.objective[:], alpha=0.3)
plt.subplot(2, 2, 2)
plt.title('Efficiency vs zshift_layer')
plt.scatter(observations.zshift_layer[:], observations.objective[:], alpha=0.3)
plt.subplot(2, 2, 3)
plt.title('Efficiency vs yoffset_plane')
plt.scatter(observations.yoffset_plane[:], observations.objective[:], alpha=0.3)
plt.subplot(2, 2, 4)
plt.title('Efficiency vs zshift_plane')
plt.scatter(observations.zshift_plane[:], observations.objective[:], alpha=0.3)

# %%
plt.hist(observations.yoffset_layer, bins=50)
plt.show()

# %%
def plot_view(x, length=5):
    
    plt.figure(figsize=(9, 16))
    pitch, yoffset_layer, yoffset_plane, zshift_layer, zshift_plane, zshift_view, alpha = x
    radius = 43.
    for plane in [0, 1]:
        for layer in [0, 1]:
            
            zs = np.array([zshift_layer * layer + zshift_plane * plane] * length)
            ys = np.cumsum([pitch] * length) - pitch + yoffset_layer * layer + yoffset_plane * plane
            plt.scatter(zs, ys, s=np.pi * radius**2, facecolor='none', edgecolors='blue')
#     plt.scatter([0], [0.5], color='red')
#     plt.scatter([0], [0], color='green')
    plt.scatter([-0.5], [-0.5], color='white')
    plt.gca().set_aspect('equal', adjustable='box')
    plt.axis("off")
    plt.show()

# %%
plot_view([  3.6       ,   1.8       ,   3.2,   1.6       ,
         6.8       ,  10.        ,   5.        ])

# %% [markdown]
# # Repeat Daniel pics

# %% [markdown]
# Fit GP model:

# %%
design = observations.dropna()[observations.columns[:-1]].values
#because we want to maximize
answers = -observations.dropna()[observations.columns[-1:]].values

kernel = GPy.kern.RBF(input_dim=7)
m = GPy.models.GPRegression(design, answers, kernel)

# %%
m.optimize(messages=True)
# Out:
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s00  0000   1.458899e+03           nan
#     07s01  0008  -4.330459e+03   2.216756e+06
#     22s26  0026  -6.036831e+03   2.998484e+03
#     26s87  0032  -6.042308e+03   6.896433e-06
#     27s68  0033  -6.042308e+03   6.896433e-06
# Runtime:     27s68
# Optimization status: Converged

# %%
m.optimize_restarts(num_restarts = 2)
# Out:
# Optimization restart 1/2, f = -6042.308401693892
# Optimization restart 2/2, f = -6042.308401671873
# [<paramz.optimization.optimization.opt_lbfgsb at 0x7f1d80a568d0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f1d80a56d30>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f1d80a56588>]

# %%
values = m.predict(design)

# %%
m.predict(np.array([[3.6, 1.9 , 1.3, 1.6, 4.2, 10., 5.]]))
# Out:
# (array([[-0.99372807]]), array([[2.70454825e-05]]))

# %%
daniel = pd.DataFrame(columns=['yoffset layer', 'yoffset plane', 'zshift layer', 'zshift plane',\
                               'estimated objective', 'std'])
daniel.loc[len(daniel)] = [19 , 13, 16, 42, -m.predict(np.array([[3.6, 1.9 , 1.3, 1.6, 4.2, 10., 5.]]))[0][0][0],\
                           m.predict(np.array([[3.6, 1.9 , 1.3, 1.6, 4.2, 10., 5.]]))[1][0][0]**0.5]
daniel.loc[len(daniel)] = [19 , 13, 18, 42, -m.predict(np.array([[3.6, 1.9 , 1.3, 1.8, 4.2, 10., 5.]]))[0][0][0],\
                           m.predict(np.array([[3.6, 1.9 , 1.3, 1.8, 4.2, 10., 5.]]))[1][0][0]**0.5]
daniel.loc[len(daniel)] = [18 , 12, 18, 44, -m.predict(np.array([[3.6, 1.8 , 1.2, 1.8, 4.4, 10., 5.]]))[0][0][0],\
                           m.predict(np.array([[3.6, 1.8 , 1.2, 1.8, 4.4, 10., 5.]]))[1][0][0]**0.5]
daniel.loc[len(daniel)] = [18 , 9, 18, 42, -m.predict(np.array([[3.6, 1.8 , 0.9, 1.8, 4.2, 10., 5.]]))[0][0][0],\
                           m.predict(np.array([[3.6, 1.8 , 0.9, 1.8, 4.2, 10., 5.]]))[1][0][0]**0.5]

# %%
daniel
# Out:
#    yoffset layer  yoffset plane  zshift layer  zshift plane  \
# 0           19.0           13.0          16.0          42.0
# 1           19.0           13.0          18.0          42.0
# 2           18.0           12.0          18.0          44.0
# 3           18.0            9.0          18.0          42.0
#
#    estimated objective       std
# 0             0.993728  0.005201
# 1             0.995609  0.002813
# 2             1.000141  0.001741
# 3             1.000074  0.001979

# %%
arm = np.array(values)[0].argmin()
arm
# Out:
# 318

# %%
m.predict_noiseless(design[arm].reshape(1, -1))
# Out:
# (array([[-1.0013945]]), array([[9.40436362e-07]]))

# %%
print(values[0][arm], values[1][arm])
# Out:
# [-1.00243861] [3.42537941e-06]

# %%
design[arm]
# Out:
# array([ 3.6       ,  1.81362205,  0.9687249 ,  1.98391634,  5.93714717,
#        10.        ,  5.        ])

# %%
len(design)
# Out:
# 335

# %%
plot_view(design[arm])

# %%
plt.hist(np.array(m.predict(design))[0], bins=100)
plt.show()

# %%
errors = []
estimated_objectives = []
best_points = []

for step in np.arange(200, 1500, 20):
    design = observations.dropna()[observations.columns[:-1]].values[:step]
    #because we want to maximize
    answers = -observations.dropna()[observations.columns[-1:]].values[:step]

    kernel = GPy.kern.RBF(input_dim=7)
    m = GPy.models.GPRegression(design, answers, kernel)
    m.optimize(messages=False)
    m.optimize_restarts(num_restarts = 2)

    values = m.predict_noiseless(design)
    arm = np.array(values)[0].argmin()
    
    errors.append(values[1][arm])
    best_points.append(arm)
    estimated_objectives.append(values[0][arm])
    print(step)
# Out:
# Optimization restart 1/2, f = -283.6176012148036
# Optimization restart 2/2, f = -283.61760121458667
# 200
# Optimization restart 1/2, f = -324.9603681812426
# Optimization restart 2/2, f = -324.9603681624684
# 220
# Optimization restart 1/2, f = -369.44645970457134
# Optimization restart 2/2, f = -369.44645965920864
# 240
# Optimization restart 1/2, f = -415.82597599011666
# Optimization restart 2/2, f = -415.8259759933579
# 260
# Optimization restart 1/2, f = -460.7308902865942
# Optimization restart 2/2, f = -460.7308903369614
# 280
# Optimization restart 1/2, f = -503.25741968230216
# Optimization restart 2/2, f = -503.2574196815792
# 300
# Optimization restart 1/2, f = -545.0105025813667
# Optimization restart 2/2, f = -545.010502581323
# 320
# Optimization restart 1/2, f = -584.3551027949288
# Optimization restart 2/2, f = -584.3551027942199
# 340
# Optimization restart 1/2, f = -634.2638075791558
# Optimization restart 2/2, f = -634.2638074517059
# 360
# Optimization restart 1/2, f = -684.7175129243199
# Optimization restart 2/2, f = -684.7175129273201
# 380
# Optimization restart 1/2, f = -735.1529859789781
# Optimization restart 2/2, f = -735.1529859794161
# 400
# Optimization restart 1/2, f = -784.5739670693905
# Optimization restart 2/2, f = -784.5739670688624
# 420
# Optimization restart 1/2, f = -832.0386366833616
# Optimization restart 2/2, f = -832.0386366818694
# 440
# Optimization restart 1/2, f = -872.8032666822935
# Optimization restart 2/2, f = -872.8032666820569
# 460
# Optimization restart 1/2, f = -915.5636092630587
# Optimization restart 2/2, f = -915.5636092614882
# 480
# Optimization restart 1/2, f = -957.0895353146495
# Optimization restart 2/2, f = -957.0895353145484
# 500
# Optimization restart 1/2, f = -1002.8522848361162
# Optimization restart 2/2, f = -1002.8522848360203
# 520
# Optimization restart 1/2, f = -1048.457531893886
# Optimization restart 2/2, f = -1048.457531877802
# 540
# Optimization restart 1/2, f = -1097.292954372649
# Optimization restart 2/2, f = -1097.292954355233
# 560
# Optimization restart 1/2, f = -1141.158471628461
# Optimization restart 2/2, f = -1141.1584716284265
# 580
# Optimization restart 1/2, f = -1189.1535752323648
# Optimization restart 2/2, f = -1189.1535753417502
# 600
# Optimization restart 1/2, f = -1237.5039223396363
# Optimization restart 2/2, f = -1237.503922327137
# 620
# Optimization restart 1/2, f = -1285.8272403391452
# Optimization restart 2/2, f = -1285.8272404283312
# 640
# Optimization restart 1/2, f = -1333.6503693444945
# Optimization restart 2/2, f = -1333.650369378331
# 660
# Optimization restart 1/2, f = -1385.3181772322498
# Optimization restart 2/2, f = -1385.3181772319542
# 680
# Optimization restart 1/2, f = -1436.9454723282315
# Optimization restart 2/2, f = -1436.945472324194
# 700
# Optimization restart 1/2, f = -1482.7341807415069
# Optimization restart 2/2, f = -1482.7341808500028
# 720
# Optimization restart 1/2, f = -1532.5593713937271
# Optimization restart 2/2, f = -1532.5593713940493
# 740
# Optimization restart 1/2, f = -1585.2408328176016
# Optimization restart 2/2, f = -1585.2408328148922
# 760
# Optimization restart 1/2, f = -1635.357265809791
# Optimization restart 2/2, f = -1635.3572658060643
# 780
# Optimization restart 1/2, f = -1689.0960538867841
# Optimization restart 2/2, f = -1689.0960539376213
# 800
# Optimization restart 1/2, f = -1739.312834007122
# Optimization restart 2/2, f = -1588.8592467514327
# 820
# Optimization restart 1/2, f = -1796.9799116974882
# Optimization restart 2/2, f = -1796.9799116990018
# 840
# Optimization restart 1/2, f = -1849.991864592188
# Optimization restart 2/2, f = -1849.991864596215
# 860
# Optimization restart 1/2, f = -1904.5488358315315
# Optimization restart 2/2, f = -1904.5488358236357
# 880
# Optimization restart 1/2, f = -1958.8232998409783
# Optimization restart 2/2, f = -1958.8232998394199
# 900
# Optimization restart 1/2, f = -2006.9452363578152
# Optimization restart 2/2, f = -2006.9452363582238
# 920
# Optimization restart 1/2, f = -2059.3539148396626
# Optimization restart 2/2, f = -2059.3539148450313
# 940
# Optimization restart 1/2, f = -2108.622790496942
# Optimization restart 2/2, f = -2108.622790538096
# 960
# Optimization restart 1/2, f = -2161.079670719604
# Optimization restart 2/2, f = -2161.0796707225754
# 980
# Optimization restart 1/2, f = -2212.1565512936886
# Optimization restart 2/2, f = -2212.1565512891534
# 1000
# Optimization restart 1/2, f = -2267.6879135818895
# Optimization restart 2/2, f = -2267.687913582012
# 1020
# Optimization restart 1/2, f = -2320.575934842065
# Optimization restart 2/2, f = -2320.575934236998
# 1040
# Optimization restart 1/2, f = -2376.672848941893
# Optimization restart 2/2, f = -2376.672848941752
# 1060
# Optimization restart 1/2, f = -2419.686369799475
# Optimization restart 2/2, f = -2419.686369791657
# 1080
# Optimization restart 1/2, f = -2474.01420492357
# Optimization restart 2/2, f = -2474.0142049221026
# 1100
# Optimization restart 1/2, f = -2526.0414008640955
# Optimization restart 2/2, f = -2526.041400828588
# 1120
# Optimization restart 1/2, f = -2573.113243068645
# Optimization restart 2/2, f = -2573.113243068118
# 1140
# Optimization restart 1/2, f = -2628.195504356063
# Optimization restart 2/2, f = -2628.1955041640585
# 1160
# Optimization restart 1/2, f = -2678.190692408468
# Optimization restart 2/2, f = -2678.1906924072428
# 1180
# Optimization restart 1/2, f = -2726.554038609419
# Optimization restart 2/2, f = -2726.554038608471
# 1200
# Optimization restart 1/2, f = -2772.1423006515083
# Optimization restart 2/2, f = -2772.1423006434006
# 1220
# Optimization restart 1/2, f = -2815.6033940547486
# Optimization restart 2/2, f = -2815.603394055442
# 1240
# Optimization restart 1/2, f = -2868.523333874327
# Optimization restart 2/2, f = -2868.52333387431
# 1260
# Optimization restart 1/2, f = -2916.952510631575
# Optimization restart 2/2, f = -2916.9525107884424
# 1280
# Optimization restart 1/2, f = -2967.1824302732616
# Optimization restart 2/2, f = -2967.182430271487
# 1300
# Optimization restart 1/2, f = -3018.971678583436
# Optimization restart 2/2, f = -3018.971678513428
# 1320
# Optimization restart 1/2, f = -3068.6587263390634
# Optimization restart 2/2, f = -3068.6587263421425
# 1340
# Optimization restart 1/2, f = -3124.562243220635
# Optimization restart 2/2, f = -3124.5622432208474
# 1360
# Optimization restart 1/2, f = -3176.176870847624
# Optimization restart 2/2, f = -3176.176871216207
# 1380
# Optimization restart 1/2, f = -3227.9657340974472
# Optimization restart 2/2, f = -3227.965734097037
# 1400
# Optimization restart 1/2, f = -3282.6080145874193
# Optimization restart 2/2, f = -3282.6080145838696
# 1420
# Optimization restart 1/2, f = -3332.844600383118
# Optimization restart 2/2, f = -3332.84460038169
# 1440
# Optimization restart 1/2, f = -3382.38258001827
# Optimization restart 2/2, f = -3382.3825773142707
# 1460
# Optimization restart 1/2, f = -3435.584897387
# Optimization restart 2/2, f = -3435.5848973897428
# 1480

# %%
np.arange(200, 1500, 20)
# Out:
# array([ 200,  220,  240,  260,  280,  300,  320,  340,  360,  380,  400,
#         420,  440,  460,  480,  500,  520,  540,  560,  580,  600,  620,
#         640,  660,  680,  700,  720,  740,  760,  780,  800,  820,  840,
#         860,  880,  900,  920,  940,  960,  980, 1000, 1020, 1040, 1060,
#        1080, 1100, 1120, 1140, 1160, 1180, 1200, 1220, 1240, 1260, 1280,
#        1300, 1320, 1340, 1360, 1380, 1400, 1420, 1440, 1460, 1480])

# %%
plt.plot(np.arange(200, 1500, 20), np.sqrt(errors))
plt.title('Error of estimate at best point')
plt.xlabel('iteration')

# %%
plt.plot(observations['yoffset_plane'][best_points], observations['zshift_plane'][best_points])

# %%
plt.figure(figsize=(20, 5))
plt.subplot(1, 2, 1)
plt.plot(np.arange(200, 1500, 20), -np.array(estimated_objectives))
plt.title('Estimated objective for best point')
plt.xlabel('iteration')
plt.subplot(1, 2, 2)
plt.plot(np.arange(200, 1500, 20), np.sqrt(errors))
plt.title('Error of estimate at best point')
plt.xlabel('iteration')
