# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# hits45 = pd.read_csv('hits.csv')

# %%
xtops45 = hits45.xtop.values
ytops45 = hits45.ytop.values
xbots45 = hits45.xbot.values
ybots45 = hits45.ybot.values

# %%
plt.figure(figsize=(16, 9))
for xtop, ytop, xbot, ybot in np.array([xtops45, ytops45, xbots45, ybots45]).T:
    plt.plot([xtop, xbot], [ytop, ybot], alpha=0.3, c='black')

# %%
temp=((xtops45-xbots45)**2+(ytops45-ybots45)**2)**0.5

# %%
plt.hist(temp, bins=50)
plt.show()

# %%
hits5 = pd.read_csv('hits.csv')
xtops5 = hits5.xtop.values
ytops5 = hits5.ytop.values
xbots5 = hits5.xbot.values
ybots5 = hits5.ybot.values

# %%
plt.figure(figsize=(16, 9))
for xtop, ytop, xbot, ybot in np.array([xtops5, ytops5, xbots5, ybots5]).T:
    plt.plot([xtop, xbot], [ytop, ybot], alpha=0.3, c='black')

# %%
temp=((xtops5-xbots5)**2+(ytops5-ybots5)**2)**0.5

# %%
plt.hist(temp, bins=50)
plt.show()
