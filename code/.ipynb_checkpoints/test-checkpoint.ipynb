# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../../check/hits.csv')

# %%
df
# Out:
#       event_id      det_id        xtop        ytop        z        xbot  \
# 0          0.0  30002268.0  249.999200   44.400000  3321.15 -249.999200
# 1          0.0  30012268.0  249.999200   45.280000  3322.25 -249.999200
# 2          0.0  30112268.0  249.999200   44.840000  3324.85 -249.999200
# 3          0.0  31012256.0  243.323488   87.218934  3332.25 -254.772267
# 4          0.0  31102255.0  243.290369   87.597488  3333.75 -254.805386
# 5          0.0  32002278.0  251.435945    5.506869  3341.15 -246.659810
# 6          0.0  32102278.0  251.397596    5.068543  3343.75 -246.698159
# 7          0.0  32112278.0  251.474293    5.945194  3344.85 -246.621462
# 8          0.0  33012266.0  249.999200   48.680000  3352.25 -249.999200
# 9          0.0  33102265.0  249.999200   49.060000  3353.75 -249.999200
# 10         0.0  40002252.0  249.999200   71.600000  3521.15 -249.999200
# 11         0.0  40112252.0  249.999200   72.040000  3524.85 -249.999200
# ...
